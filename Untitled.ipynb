# %%
import pandas as pd

# %%
# reading the csv files
saf = pd.read_csv(
    "/Users/briankimanzi/Documents/programmingLanguages/PythonProgramming/ReviewsProject/CleanCompanyRev/Safaricom.csv")
google = pd.read_csv(
    "/Users/briankimanzi/Documents/programmingLanguages/PythonProgramming/ReviewsProject/CleanCompanyRev/Google.csv")
microsoft = pd.read_csv(
    "/Users/briankimanzi/Documents/programmingLanguages/PythonProgramming/ReviewsProject/CleanCompanyRev/Microsoft.csv")
kcb = pd.read_csv(
    "/Users/briankimanzi/Documents/programmingLanguages/PythonProgramming/ReviewsProject/CleanCompanyRev/KCB.csv")
ibm = pd.read_csv(
    "/Users/briankimanzi/Documents/programmingLanguages/PythonProgramming/ReviewsProject/CleanCompanyRev/IBM.csv")
cisco = pd.read_csv(
    "/Users/briankimanzi/Documents/programmingLanguages/PythonProgramming/ReviewsProject/CleanCompanyRev/Cisco.csv")
bolt = pd.read_csv(
    "/Users/briankimanzi/Documents/programmingLanguages/PythonProgramming/ReviewsProject/CleanCompanyRev/Bolt.csv")
co_op = pd.read_csv(
    "/Users/briankimanzi/Documents/programmingLanguages/PythonProgramming/ReviewsProject/CleanCompanyRev/Co_operative.csv")
equity = pd.read_csv(
    "/Users/briankimanzi/Documents/programmingLanguages/PythonProgramming/ReviewsProject/CleanCompanyRev/Equity.csv")

# %%
saf
# Out:
#                                      Job Title  Job Rating        Time  \
# 0                             Brand Ambassador         5.0  2025-08-08
# 1                      Senior Mobile Developer         4.0  2025-07-28
# 2                              Project Manager         4.0  2025-07-15
# 3                               Ict Technician         5.0  2025-07-18
# 4                                       Intern         5.0  2025-07-15
# ..                                         ...         ...         ...
# 493              Network Optimization Engineer         5.0  2021-02-03
# 494                     Information Technology         3.0  2021-04-14
# 495                              Legal Officer         3.0  2021-05-13
# 496  Telecommunications Engineering Specialist         4.0  2021-06-13
# 497                         Senior Ux Designer         2.0  2022-06-20
#
#                                 Job Status  \
# 0        Former employee, more than 1 year
# ...

# %%
google
# Out:
#                                 Job Title  Job Rating        Time  \
# 0                         Program Manager         4.0  2013-06-21
# 1                   Software Engineer Iii         5.0  2014-05-10
# 2                      Anonymous Employee         5.0  2015-02-08
# 3     Software Development Engineer (Sde)         4.0  2025-07-28
# 4                         Account Manager         1.0  2025-07-08
# ...                                   ...         ...         ...
# 4909                        Boat Mechanic         5.0  2022-08-17
# 4910                        Cvg Marketing         4.0  2022-09-02
# 4911                              Actuary         5.0  2022-09-08
# 4912         Senior Information Developer         5.0  2022-09-11
# 4913                 Corporate Tax Intern         4.0  2022-09-19
#
#                               Job Status  \
# 0     Former employee, more than 8 years
# 1     Current employee, more than 1 year
# 2                       Current employee
# ...

# %%
microsoft
# Out:
#                           Job Title  Job Rating        Time  \
# 0            Senior Product Manager         5.0  2025-08-12
# 1                Anonymous Employee         4.0  2013-01-28
# 2                 Product Manager 2         2.0  2025-08-06
# 3                   Product Manager         4.0  2025-07-18
# 4     Senior Data Center Technician         4.0  2025-08-10
# ...                             ...         ...         ...
# 5177                   Radiographer         1.0  2019-07-16
# 5178                            Dct         1.0  2021-04-01
# 5179                            Tss         1.0  2015-11-20
# 5180               Mobile Developer         1.0  2021-10-23
# 5181                  Bruh Licenser         1.0  2022-02-02
#
#                                 Job Status  \
# 0      Current employee, more than 5 years
# 1     Current employee, more than 10 years
# 2      Current employee, more than 5 years
# 3      Former employee, more than 10 years
# ...

# %%
kcb
# Out:
#                             Job Title  Job Rating        Time  \
# 0     Certified nursing assistant cna         1.0  2024-03-12
# 1              Cyber security analyst         5.0  2025-07-23
# 2                        Bank officer         5.0  2025-07-28
# 3                    Finacial analyst         5.0  2025-07-14
# 4                   Finance executive         5.0  2025-07-16
# 5      Senior risk management analyst         5.0  2025-07-13
# 6               Bancassurance officer         5.0  2025-06-23
# 7                  Anonymous employee         4.0  2025-06-01
# 8         Direct sales representative         4.0  2025-05-20
# 9               Transition specialist         3.0  2025-05-08
# 10    Application security specialist         4.0  2025-01-20
# 11                             Intern         3.0  2025-02-25
# 12  Direct sales representative (dsr)         3.0  2025-03-18
# 13                       Data analyst         5.0  2025-01-25
# ...

# %%
ibm
# Out:
#                                    Job Title  Job Rating        Time  \
# 0                         Anonymous Employee         5.0  2025-08-12
# 1                          Advisory Engineer         4.0  2014-08-26
# 2                            Ibm Cloud Sales         4.0  2025-08-07
# 3       Customer Success Manager - Architect         3.0  2025-06-16
# 4                    Application Developer 2         4.0  2025-06-11
# ...                                      ...         ...         ...
# 10542                              Tsm Sales         1.0  2021-09-24
# 10543                         Wms Consultant         1.0  2021-09-29
# 10544                Senior Resource Manager         1.0  2021-10-20
# 10545                     Performance Leader         1.0  2022-05-29
# 10546  Business Sales Leadership Development         1.0  2022-06-06
#
#                                  Job Status  \
# 0       Current employee, more than 3 years
# 1       Current employee, more than 8 years
# ...

# %%
cisco
# Out:
#                              Job Title  Job Rating        Time  \
# 0            Manager, Network Services         4.0  2015-03-13
# 1                     Systems Engineer         3.0  2025-08-05
# 2                  Strategy & Planning         4.0  2025-07-08
# 3                      Human Resources         3.0  2025-08-12
# 4                   Solutions Engineer         4.0  2025-08-10
# ...                                ...         ...         ...
# 3414                    Devop Engineer         1.0  2022-02-24
# 3415                               Crs         1.0  2019-06-22
# 3416                      Hpc Engineer         1.0  2020-07-02
# 3417                   Loss Prevention         1.0  2021-09-07
# 3418  Professional Services Management         1.0  2021-09-26
#
#                                Job Status  \
# 0      Former employee, more than 3 years
# 1      Former employee, more than 8 years
# 2                         Former employee
# ...

# %%
bolt
# Out:
#                                     Job Title  Job Rating        Time  \
# 0   Business development representative (bdr)         5.0  2024-11-02
# 1                          Solutions engineer         2.0  2025-06-26
# 2                    Senior software engineer         4.0  2025-02-04
# 3                          Anonymous employee         4.0  2025-01-16
# 4                  Revenue operations analyst         3.0  2024-11-10
# ..                                        ...         ...         ...
# 71                                   Designer         5.0  2021-01-08
# 72                   Senior account executive         1.0  2022-09-01
# 73                                      Sde-2         4.0  2025-05-27
# 74                       Integration engineer         2.0  2024-07-17
# 75            Social media support specialist         4.0  2024-06-29
#
#                              Job Status  \
# 0   Current employee, more than 3 years
# 1     Former employee, more than 1 year
# ...

# %%
co_op
# Out:
#                                    Job Title  Job Rating        Time  \
# 0                         Anonymous employee         4.0  2025-05-28
# 1     Business development executive manager         4.0  2024-02-27
# 2                         Operations manager         4.0  2024-03-05
# 3                                    Support         3.0  2017-07-09
# 4                              Legal officer         3.0  2021-01-16
# ..                                       ...         ...         ...
# 133                 Ict service desk analyst         3.0  2021-02-21
# 134                           Senior manager         2.0  2021-04-12
# 135  Bancassurance finance & support manager         3.0  2021-06-15
# 136                          Devops engineer         3.0  2021-11-22
# 137                                      Ict         3.0  2015-07-15
#
#                               Job Status  \
# 0                       Current employee
# 1                       Current employee
# ...

# %%
equity
# Out:
#                    Job Title  Job Rating        Time  \
# 0       Credit administrator         5.0  2022-06-30
# 1           Sr. acct manager         1.0  2024-12-20
# 2         Anonymous employee         4.0  2023-07-28
# 3                Bank teller         2.0  2021-03-01
# 4       Relationship officer         4.0  2020-12-03
# ..                       ...         ...         ...
# 263         Planning officer         4.0  2022-03-31
# 264  Senior business analyst         4.0  2022-05-14
# 265   Senior program manager         3.0  2016-05-02
# 266    Ban assurance officer         1.0  2022-10-17
# 267   Channel administrative         1.0  2013-10-09
#
#                              Job Status  \
# 0    Former employee, more than 5 years
# 1    Former employee, more than 5 years
# 2                      Current employee
# 3     Former employee, more than 1 year
# 4     Former employee, less than 1 year
# ..                                  ...
# ...
